# %% [markdown]
# Este notebook fue complementado con el trabajo del miembro de la comunidad Joaquin Millian, quien despues de un hard Reset, nos salvo y gracias a el recuperamos el proyecto!
#
# Redes Sociales de Joaquin:
# - [Linkedin](https://www.linkedin.com/)

# %%
import numpy as np
import pandas as pd
import gradio as gr
import seaborn as sns
import matplotlib.pyplot as plt

import plotly.graph_objs as go
from plotly.subplots import make_subplots
from plotly.express import colors

from Readers.SQLiteReader import SQLiteReader
from Readers.dataframe_reader import DataFrameReader

from Formatters.OHLCVFormatter import OHLCVFormatter
from Formatters.ArticleFormatter import ArticleFormatter

# %% [markdown]
# # Importar DFs

# %%
# Conexion con la df
dbReader = SQLiteReader()
dbReader.connect("../news_analyzer.db")

articles = dbReader.read("SELECT * FROM articles")
article_formatter = ArticleFormatter()
articles = article_formatter.format(articles)
df_articles = article_formatter.ListToDF(articles)
print(f'Antes hay {df_articles.shape[0]} articulos')

df_clean = article_formatter.only_englishnews(df_articles)
print(f'Antes hay {df_clean.shape[0]} articulos')

df_sum = article_formatter.ResampleDF(df_clean[['sentiment']], '1D')
df_sum['rolling_mean_sentiment'] = df_sum['sentiment'].rolling(7).mean()
df_sum['rolling_std_sentiment'] = df_sum['sentiment'].rolling(7).std()
df_sum.dropna(inplace=True)

df_sum.tail()
# Out:
# Antes hay 41385 articulos
# Antes hay 40451 articulos
#             sentiment  rolling_mean_sentiment  rolling_std_sentiment
# datetime
# 2023-11-27     9.1049                5.185586               4.979931
# 2023-11-28     8.4440                4.417957               3.669299
# 2023-11-29    12.0358                5.280271               4.674529
# 2023-11-30    14.1033                6.761814               5.644951
# 2023-12-01     7.0387                7.246671               5.475817

# %%
# Cargar las cotizaciones
path_ohlcv = "../data/BTCUSD.csv"
ohlcv_formatter = OHLCVFormatter()
df_reader = DataFrameReader(path_ohlcv)
df_reader.read()
df_ohlcv = df_reader.format(ohlcv_formatter.format)
df_ohlcv['log_returns'] = np.log( df_ohlcv['close']/df_ohlcv['close'].shift(1))
df_ohlcv['rolling_mean_close'] = df_ohlcv['close'].rolling(7).mean()
df_ohlcv['rolling_std_close'] = df_ohlcv['close'].rolling(7).std()
df_ohlcv.dropna(inplace=True)  # Pasa lo mismo que con df_sum

df_ohlcv.tail()
# Out:
#                 open      high       low     close  volume  log_returns  \
# datetime
# 2023-11-30  37870.85  38148.48  37513.42  37728.97     0.0    -0.003754
# 2023-12-01  37727.75  38983.54  37622.28  38688.85     0.0     0.025123
# 2023-12-02  38688.85  39717.12  38659.66  39471.17     0.0     0.020019
# 2023-12-03  39471.04  40203.62  39292.85  39988.27     0.0     0.013016
# 2023-12-04  39988.18  41801.88  39986.31  41695.08     0.0     0.041797
#
#             rolling_mean_close  rolling_std_close
# datetime
# 2023-11-30        37666.755714         223.921984
# 2023-12-01        37805.464286         448.744149
# 2023-12-02        38042.805714         773.355038
# 2023-12-03        38403.154286        1010.894056
# 2023-12-04        39037.345714        1462.661088

# %% [markdown]
# # Analisis Exploratorio

# %% [markdown]
# ## Distribucciones

# %%
# Histograma del sentimiento
plt.figure(figsize=(20,8))
plt.hist(df_sum['sentiment'], bins=100)
plt.show()

# %%
# Histograma de los retornos
plt.figure(figsize=(20,8))
plt.hist(df_ohlcv['log_returns'], bins=100)
plt.show()

# %% [markdown]
# ## Cotizacion junto a la evolución del sentimiento

# %%
# Representar subplot cotizacion, sentimiento
fig, ax = plt.subplots(2, 1, figsize=(20, 15))

ax[0].plot(df_ohlcv.loc['2013-04-13':, 'close'])
ax[0].set_ylabel('Precio', fontsize=20)
ax[0].set_title('Evolución del precio de Cierre de Bitcoin', fontsize=30, fontweight='bold', loc='left')

ax[1].plot(df_sum['sentiment'], label='Sentimiento')
ax[1].plot(df_sum['rolling_mean_sentiment'], label='Rolling_mean')
ax[1].set_xlabel('Datetime', fontsize=20)
ax[1].set_ylabel('Sentimiento agregado', fontsize=20)
ax[1].set_title('Evolución del sentimiento de las noticias', fontsize=30, fontweight='bold', loc='left')
ax[1].legend(fontsize=20)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Zscore sentiment y Zscore close prices

# %%
# Veamos la comparación entre z_score del precio y del sentimiento
df_sum['rolling_zscore_sentiment'] = ((df_sum['sentiment'] - df_sum['rolling_mean_sentiment'])
                                      /df_sum['rolling_std_sentiment'])

df_ohlcv['rolling_zscore_close'] = ((df_ohlcv['close'] - df_ohlcv['rolling_mean_close'])
                                      /df_ohlcv['rolling_std_close'])
                 
                                      
# Representar
fig, ax = plt.subplots(2, 1, figsize=(12, 8))

ax[0].plot(df_ohlcv.loc['2013-04-13':, 'rolling_zscore_close'])
ax[0].set_ylabel('Precio normalizado')

ax[1].plot(df_sum['rolling_zscore_sentiment'])
ax[1].set_xlabel('Fecha')
ax[1].set_ylabel('Sentimiento Normalizado')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Anomalias

# %%
# Calcular las anomalias positivas y negativas
threshold = 1.5
mask_anomalias_positivas = df_sum['rolling_zscore_sentiment'] > threshold
mask_anomalias_negativas = df_sum['rolling_zscore_sentiment'] < -threshold

anomalias_positivas = df_sum.loc[mask_anomalias_positivas, 'rolling_zscore_sentiment']
anomalias_negativas = df_sum.loc[mask_anomalias_negativas, 'rolling_zscore_sentiment']

df_sum['positive_anomalie_index'] = df_sum['rolling_zscore_sentiment'].apply(lambda x: 1 if x > threshold else 0)
df_sum['negative_anomalie_index'] = df_sum['rolling_zscore_sentiment'].apply(lambda x: 1 if x < -threshold else 0)

# Representar las anomalias de precio
sns.set_style("whitegrid")
plt.figure(figsize=(20,10))

plt.plot(df_sum['rolling_zscore_sentiment'], label='zscore_sentiment')
plt.scatter(anomalias_positivas.index, anomalias_positivas, color='g')
plt.scatter(anomalias_negativas.index, anomalias_negativas, color='r')
plt.hlines(threshold, df_sum['rolling_zscore_sentiment'].index[0], 
           df_sum['rolling_zscore_sentiment'].index[-1],color='g')
plt.hlines(-threshold, df_sum['rolling_zscore_sentiment'].index[0], 
           df_sum['rolling_zscore_sentiment'].index[-1],color='r')


plt.xlabel('Datetime', fontweight='bold', fontsize=20)
plt.title('Sentimiento ZScore y Anomalias', loc='left', fontweight='bold', fontsize=30)

plt.tight_layout()
plt.show()

# %%
# Vamos a calcular la media y la desviacion tipica del Zscore del sentiment para ver como ajustar el threshold
media = df_sum['rolling_zscore_sentiment'].mean()
desvesta = df_sum['rolling_zscore_sentiment'].std()
print('Media de Zscore = {}'.format(media))
print('Desviación Típica de Zscore = {}'.format(desvesta))
print('El threshold sería = {}'.format(media+desvesta))
# Out:
# Media de Zscore = 0.004923580799080212
# Desviación Típica de Zscore = 0.9370241610187758
# El threshold sería = 0.941947741817856

# %% [markdown]
# # Correlación entre zscore sentiment y zscore close

# %%
# Creamos un df conjunto desde la primera fecha
# ini_fecha = df_sum.index[0]
ini_fecha = '2014-01-01'
ini_final = df_ohlcv.index[df_ohlcv.shape[0]-4]
cotizaciones = df_ohlcv.loc[ini_fecha:ini_final, 'log_returns']
sentimiento = df_sum.loc[ini_fecha:, 'rolling_zscore_sentiment']

print(f'Cotizaciones tiene {len(cotizaciones)} valores')
print(f'Sentimiento tiene {len(sentimiento)} valores')

print(f'La correlación entre Logreturns y el Sentimiento = {cotizaciones.corr(sentimiento)}')

# Scatter plot
plt.figure(figsize=(20,10))
plt.scatter(sentimiento, cotizaciones)
plt.xlabel('Zscore Sentiment', fontsize=15)
plt.ylabel('Log returns', fontsize=15)
plt.title('Scatterplot Logreturns vs Zscore', fontsize=25, fontweight='bold', loc='left')
plt.show()
# Out:
# Cotizaciones tiene 3622 valores
# Sentimiento tiene 3622 valores
# La correlación entre Logreturns y el Sentimiento = 0.049348977296962256

# %% [markdown]
# No hemos tenido una correlación muy alta entre las variables de manera directa veamos si los retornos a dias posteriores 1 o 7 días son mejores en cuanto a correlación y resultados

# %% [markdown]
# # ¿Las noticias de hoy explican los retornos de mañana?

# %%
# Ahora veremos la correlación directa entre las variables
ini_fecha = '2014-01-01'
ini_final = df_ohlcv.index[df_ohlcv.shape[0]-4]
cotizaciones = df_ohlcv.loc[ini_fecha:ini_final, 'log_returns']
sentimiento = df_sum.loc[ini_fecha:, 'rolling_zscore_sentiment']

print(f'Cotizaciones tiene {len(cotizaciones)} valores')
print(f'Sentimiento tiene {len(sentimiento)} valores')

print(f'La correlación entre Logreturns desfasado 1 dia y el Sentimiento = {cotizaciones.shift(1).corr(sentimiento)}')
print(f'La correlación entre Logreturns desfasado 7 dias y el Sentimiento = {cotizaciones.shift(7).corr(sentimiento)}')
# Out:
# Cotizaciones tiene 3622 valores
# Sentimiento tiene 3622 valores
# La correlación entre Logreturns desfasado 1 dia y el Sentimiento = 0.04039516909670457
# La correlación entre Logreturns desfasado 7 dias y el Sentimiento = -0.014877655278194483

# %% [markdown]
# No parece que mejore el resultado, veamos como evolucionarian los retornos en caso de compraramos por una anomalia positiva

# %%
return_anomaly_positive = []
index_fechas = []
for anomaly in anomalias_positivas.index:
    aux = sum(df_ohlcv.loc[(anomaly + pd.Timedelta(days=1)):(anomaly + pd.Timedelta(days=7)), 'log_returns'])
    return_anomaly_positive.append(aux)
    index_fechas.append(anomaly + pd.Timedelta(days=7))

# Convertimos a acumulado
return_anomaly_positive = pd.Series(return_anomaly_positive)
return_anomaly_positive = return_anomaly_positive.cumsum()

# Representamos el retorno en si 
plt.figure(figsize=(20, 10))
plt.plot(index_fechas, return_anomaly_positive)
plt.ylabel('Retorno logaritmico acumulado')
plt.show()

# %% [markdown]
# Obtiene retorno positivo pero veamos cuanto en comparación con el Hold en ese mismo periodo

# %%
return_anomaly_positive_lineal = (np.exp(return_anomaly_positive) - 1.0) * 100

# Calcular los retornos de hold
index_ini = anomalias_positivas.index[0] + pd.Timedelta(days=1)
index_fin = anomalias_positivas.index[len(anomalias_positivas)-1] + pd.Timedelta(days=7)
retornos_hold = df_ohlcv.loc[index_ini:index_fin,'log_returns']

# Volver retorno acumulado
retornos_hold = retornos_hold.cumsum()
retornos_hold_lineal = (np.exp(retornos_hold) - 1.0) * 100

# Representamos el retorno de hold y de las noticias
plt.figure(figsize=(20, 10))
plt.plot(retornos_hold_lineal, label='Estrategia hold')
plt.plot(index_fechas, return_anomaly_positive_lineal, label='Estrategia anomalias positivas')
plt.legend()
plt.ylabel('Retorno acumulado (%)')
plt.show()

# %% [markdown]
# Su retorno porcentual acaba siendo mucho peor que el caso de Hold

# %% [markdown]
# # ¿Los autores tienen un sentimiento sesgado?

# %%
# Vamos a ver cuantos autores tenemos
autores = np.unique(df_clean['author'])
print(f'Hay {len(autores)} autores distintos')
# Out:
# Hay 423 autores distintos

# %%
plt.figure(figsize=(20,10))

means = []
stds = []
for autor in autores:
    mask_autor = df_clean['author'] == autor
    df_author = df_clean.loc[mask_autor,['author', 'sentiment']]
    df_author = article_formatter.ResampleDF(df_author[['sentiment']], '1D')
    means.append(df_author['sentiment'].mean())
    stds.append(df_author['sentiment'].std())
    print('{}, sentimiento = {:.2f}+-{:.2f}'.format(autor, df_author['sentiment'].mean(), df_author['sentiment'].std()))
    
    plt.plot(df_author['sentiment'], label=autor)
    
plt.show()
# Out:
#  Deirdra  Funcheon, sentimiento = 0.36+-0.68
# Aaron Stanley, sentimiento = 0.03+-0.18
# Aaron van Wirdum, sentimiento = 0.08+-0.32
# Ada Hui, sentimiento = 0.01+-0.15
# Adam B. Levine, sentimiento = 0.15+-0.46
# Adam Draper, sentimiento = 1.00+-nan
# Adam Hanft, sentimiento = 1.00+-nan
# Adam Hart, sentimiento = 1.00+-nan
# Adam Krellenstein, sentimiento = 1.00+-nan
# Adam Ludwin, sentimiento = 0.94+-nan
# Aditi Hudli, sentimiento = 0.15+-0.41
# Alex Brokaw, sentimiento = 0.99+-0.01
# Alex Sunnarborg, sentimiento = 0.03+-0.18
# Alexander Zaitchik, sentimiento = 1.99+-nan
# Alice Truong, sentimiento = 0.40+-0.64
# Alp Börü, sentimiento = 0.02+-0.14
# Alyssa Hertig, sentimiento = 0.09+-0.36
# Alyssa Hertig, Stan Higgins &amp; Garrett Keirns, sentimiento = 1.00+-nan
# Ami Ben David, sentimiento = 1.00+-nan
# Amitoj Singh, sentimiento = 0.18+-0.52
# Amor Sexton, sentimiento = 1.00+-nan
# Amy Castor, sentimiento = 0.15+-0.46
# Anatol Antonovici, sentimiento = -0.98+-nan
# Andrew Thurman, sentimiento = 0.39+-0.68
# Andrew Torba, sentimiento = 0.15+-0.36
# Andrey Sergeenkov, sentimiento = 0.06+-0.23
# Andrés Engler, sentimiento = 0.10+-0.36
# Angelique Chen, sentimiento = 0.11+-0.38
# Anna Baydakova, sentimiento = 0.14+-0.50
# Annaliese Milano, sentimiento = 0.18+-0.64
# Annika Feign, sentimiento = 1.00+-nan
# Antonis Polemitis, sentimiento = -1.00+-nan
# Antony Lewis, sentimiento = 1.00+-nan
# Aoyon Ashraf, sentimiento = 0.15+-0.47
# Ariel Deschapell, sentimiento = 0.00+-0.06
# Ariella Brown, sentimiento = 0.14+-0.35
# Asa Sanon-Jules, sentimiento = 0.05+-0.21
# Ash Bennington, sentimiento = 0.31+-0.48
# Austin Reynolds, sentimiento = 1.00+-nan
# Bailey Reutzel, sentimiento = 0.02+-0.18
# Bailey Reutzel &amp; Pete Rizzo, sentimiento = 2.00+-nan
# Bailey Reutzel, Marc Hochstein &amp; Stan Higgins, sentimiento = 0.97+-nan
# Balaji Srinivasan, sentimiento = 1.00+-nan
# Başak Çetinbülüç, sentimiento = 0.99+-nan
# Belen Marty, sentimiento = 0.11+-0.32
# Ben Chan, sentimiento = 1.00+-nan
# Ben Munster, sentimiento = 1.00+-nan
# Ben Schiller, sentimiento = 0.02+-0.14
# Benedict Alibasa, sentimiento = 0.72+-0.87
# Benedict George, sentimiento = 0.01+-0.10
# Benjamin Powers, sentimiento = 0.19+-0.55
# Bill Barhydt, sentimiento = 1.00+-nan
# Blake Cantrel, sentimiento = 0.99+-nan
# Bob Swarup, sentimiento = 0.07+-0.26
# Bobby Lee, sentimiento = 1.00+-nan
# Bradley Keoun, sentimiento = 0.15+-0.45
# Bradley Miles, sentimiento = 0.00+-0.12
# Brady Dale, sentimiento = 0.34+-0.59
# Brandy Betz, sentimiento = 0.52+-0.84
# Brian Childs, sentimiento = 0.97+-nan
# Brian Evans, sentimiento = -0.04+-0.37
# Brian Klein, sentimiento = 0.99+-nan
# Bruce Fenton, sentimiento = 1.00+-nan
# Cam Thompson, sentimiento = 0.21+-0.52
# Cameron Harwick, sentimiento = 1.00+-nan
# Cameron Hood, sentimiento = 0.02+-0.14
# Cameron Thompson, sentimiento = 0.54+-0.40
# Camila Russo, sentimiento = 1.00+-nan
# Camomile Shumba, sentimiento = 0.20+-0.55
# Carolyn Wilkins, sentimiento = 1.00+-nan
# Carrie Kirby, sentimiento = 0.05+-0.36
# Cathy Reisenwitz, sentimiento = 0.93+-nan
# Charles Bovaird, sentimiento = 0.27+-0.52
# Charlie Shrem, sentimiento = 1.00+-nan
# Chelsea Palmer, sentimiento = 0.99+-nan
# Cheyenne Ligon, sentimiento = 0.10+-0.60
# Christie Harkin, sentimiento = 0.02+-0.14
# Christine Kim, sentimiento = 0.19+-0.51
# Christine Lee, sentimiento = -0.00+-0.03
# Christoph Cronimund, sentimiento = 0.05+-0.22
# Christopher Robbins, sentimiento = 0.08+-0.27
# Chuan Tian, sentimiento = 0.03+-0.26
# CoinDesk, sentimiento = 0.01+-0.13
# CoinDesk China, sentimiento = 1.00+-nan
# CoinDesk Deals, sentimiento = 0.98+-nan
# CoinDesk Indices, sentimiento = 1.00+-nan
# CoinDesk Staff, sentimiento = 0.01+-0.19
# Colin Harper, sentimiento = 0.25+-0.70
# Conrad Barski &amp; Chris Wilmer, sentimiento = 1.00+-nan
# Corin Faife, sentimiento = 0.11+-0.37
# Cyrus Rothwell-Ferraris, sentimiento = 0.74+-1.12
# D.A. Wallach, sentimiento = 1.00+-nan
# Damanick Dantes, sentimiento = 0.49+-0.89
# Dan  Jeffries, sentimiento = 1.00+-nan
# Dan Elitzer &amp; Jeremy Rubin, sentimiento = 1.00+-nan
# Dan Held, sentimiento = 0.28+-0.65
# Dan Ilett, sentimiento = 0.16+-0.50
# Dan Jeffries, sentimiento = 1.00+-nan
# Daniel Cawrey, sentimiento = 0.16+-0.42
# Daniel Evans, sentimiento = 1.00+-nan
# Daniel Kuhn, sentimiento = 0.27+-0.66
# Daniel Palmer, sentimiento = 0.17+-0.57
# Danny Bradbury, sentimiento = 0.28+-0.62
# Danny Nelson, sentimiento = 0.34+-0.75
# Dante Sacco, sentimiento = 1.00+-nan
# Dario Di Pardo, sentimiento = 0.02+-0.16
# David Floyd, sentimiento = 0.25+-0.61
# David Gilbert, sentimiento = 0.89+-nan
# David Gilson, sentimiento = 0.30+-0.63
# David Lu, sentimiento = 1.00+-nan
# David Pan, sentimiento = 0.17+-0.50
# David Schwartz, sentimiento = 0.99+-nan
# David Weisberger, sentimiento = 0.99+-nan
# David Z. Morris, sentimiento = 0.03+-0.23
# Diana Aguilar, sentimiento = 0.06+-0.28
# Dilin Massand, sentimiento = 0.98+-nan
# Dominic Frisby, sentimiento = 0.12+-0.33
# Don &amp; Alex Tapscott, sentimiento = 1.00+-nan
# Don Tapscott, sentimiento = 1.00+-nan
# Donna Redel, sentimiento = 1.00+-nan
# Doreen Wang, sentimiento = 0.15+-0.48
# Dorian  Batycka, sentimiento = 1.00+-nan
# Doug Watt, sentimiento = 0.37+-0.65
# Dovey Wan, sentimiento = 0.01+-0.09
# Dr. Aisha Bin Bishr, sentimiento = 1.00+-nan
# Dr. Paul J. Ennis, sentimiento = 0.98+-nan
# Drew Pierson, sentimiento = 0.07+-0.26
# Duy Nguyen, sentimiento = 0.99+-nan
# Edan Yago, sentimiento = 0.00+-0.03
# Edward Oosterbaan, sentimiento = 0.08+-0.27
# Eitan Jankelewitz, sentimiento = 0.98+-nan
# Ekin Genç, sentimiento = 0.43+-0.53
# Elaine Ramirez, sentimiento = 0.01+-0.08
# Eleanor Pahl, sentimiento = 0.15+-nan
# Eli Tan, sentimiento = 0.31+-0.59
# Elise Hansen, sentimiento = 0.51+-nan
# Eliza Gkritsi, sentimiento = 0.17+-0.53
# Elizabeth Machuca, sentimiento = 2.86+-nan
# Elizabeth Napolitano, sentimiento = 0.09+-0.53
# Emerson Dameron, sentimiento = 0.99+-nan
# Emily Faber, sentimiento = 0.07+-0.26
# Emily Parker, sentimiento = 0.00+-0.05
# Emily Spaven, sentimiento = 0.15+-0.47
# Emma Stamm, sentimiento = 1.00+-nan
# Eric Mu, sentimiento = 0.01+-0.09
# Eric Rykwalder, sentimiento = 0.03+-0.16
# Erik Voorhees, sentimiento = 0.00+-0.03
# Eswar Prasad, sentimiento = 1.00+-nan
# Ethan Lou, sentimiento = -0.66+-0.57
# Evan Engel, sentimiento = 0.00+-0.00
# Evan Kuo, sentimiento = 1.00+-nan
# Ezra Galston, sentimiento = 0.91+-nan
# Faisal Khan, sentimiento = 0.99+-nan
# Felix Im, sentimiento = 0.07+-0.26
# Forkast News, sentimiento = 1.50+-0.70
# Fran Velasquez, sentimiento = 0.19+-0.45
# Frances Yue, sentimiento = 0.22+-0.53
# Fred Wilson, sentimiento = 0.99+-nan
# Frederick  Munawa, sentimiento = 0.16+-0.44
# Frederick Reese, sentimiento = 0.02+-0.18
# Galen Moore, sentimiento = 0.02+-0.16
# Garrett Keirns, sentimiento = 0.96+-1.13
# Garrett Keirns &amp; Michael del Castillo, sentimiento = 0.95+-nan
# Garrick Hileman, sentimiento = 0.01+-0.08
# Gary McFarlane, sentimiento = 0.00+-0.31
# George Chidi, sentimiento = -0.58+-nan
# George Kaloudis, sentimiento = 0.01+-0.11
# George McDonaugh, sentimiento = 0.99+-nan
# George Papazov, sentimiento = 0.10+-0.30
# George Samman, sentimiento = 0.99+-nan
# George Yacik, sentimiento = 0.07+-0.27
# Gideon Greenspan &amp; Maya Zehavi, sentimiento = 1.00+-nan
# Gleb Kostarev, sentimiento = -0.93+-nan
# Glenn Williams, sentimiento = 0.45+-0.52
# Grace Caffyn, sentimiento = 0.09+-0.35
# Greg Ahlstrand, sentimiento = 0.02+-0.15
# Guy  Hedgecoe, sentimiento = 1.00+-nan
# Guy Zyskind, sentimiento = 0.99+-nan
# Hannah Summersfield, sentimiento = 0.99+-nan
# Hass McCook, sentimiento = 0.12+-0.34
# Hayden Gill, sentimiento = 0.99+-nan
# Helen Thompson, sentimiento = 1.00+-nan
# Helene Braun, sentimiento = 0.15+-0.49
# Hemant Taneja, sentimiento = 1.00+-nan
# Hoa Nguyen, sentimiento = 0.74+-nan
# Ian Allison, sentimiento = 0.33+-0.67
# Ian DeMartino, sentimiento = 0.00+-0.19
# Iliana Oris Valiente, sentimiento = 1.00+-nan
# Inseon Chung, sentimiento = 0.87+-nan
# J Christopher Giancarlo, sentimiento = 1.00+-nan
# JP Koning, sentimiento = 0.38+-nan
# Jacek Czarnecki, sentimiento = 0.01+-0.10
# Jack Schickler, sentimiento = 0.27+-0.77
# Jack Wang, sentimiento = 1.00+-nan
# Jacob Donnelly, sentimiento = 0.08+-0.33
# James Downer, sentimiento = 0.00+-0.07
# James Rubin, sentimiento = 0.19+-0.52
# Jameson Lopp, sentimiento = 0.02+-0.13
# Jamie Crawley, sentimiento = 0.32+-0.65
# Janine Yorio, sentimiento = 1.00+-nan
# Jared Lindzon, sentimiento = 1.00+-nan
# Jared Paul Marx, sentimiento = 0.87+-nan
# Jaroslaw Adamowski, sentimiento = 0.01+-0.12
# Jason Leibowitz, sentimiento = 1.00+-nan
# Jason Tyra, sentimiento = 0.02+-0.18
# Jaspreet Kalra, sentimiento = 0.15+-0.48
# Jeanhee Kim, sentimiento = 0.99+-nan
# Jeff  Wilser, sentimiento = 0.03+-0.19
# Jeff Roberts, sentimiento = 1.00+-nan
# Jeff Wilser, sentimiento = 0.05+-0.22
# Jeremy Bonney, sentimiento = 0.03+-0.15
# Jeremy Millar, sentimiento = 0.99+-nan
# Jerry Brito, sentimiento = 1.00+-nan
# Jesse Hamilton, sentimiento = 0.18+-0.58
# Jesse Powell, sentimiento = 0.99+-nan
# Jessica  Klein, sentimiento = 0.16+-0.37
# Jessica Klein, sentimiento = 0.01+-0.12
# Jill Carlson, sentimiento = 0.02+-0.13
# Jillian Godsil, sentimiento = 0.03+-0.18
# Jim Harper, sentimiento = 1.00+-nan
# Jimmy He, sentimiento = 0.18+-0.57
# Jimmy Song, sentimiento = -0.06+-0.31
# Joanne Po, sentimiento = 1.00+-nan
# Jocelyn Yang, sentimiento = 0.27+-0.60
# Jodie Gunzberg, sentimiento = 0.03+-0.21
# Joe Lautzenhiser, sentimiento = 0.01+-0.07
# Joel Monegro, sentimiento = 1.00+-nan
# Joey Prebys, sentimiento = 1.00+-nan
# John Beccia, sentimiento = 1.00+-nan
# John Biggs, sentimiento = 0.20+-0.58
# John Henderson, sentimiento = 0.99+-nan
# John Law, sentimiento = 0.13+-0.34
# John Oates, sentimiento = 0.43+-0.79
# Jon Matonis, sentimiento = 0.06+-0.25
# Jon Southurst, sentimiento = 0.35+-0.70
# Jona Kallgren, sentimiento = 0.06+-0.23
# Jonathan Darcie, sentimiento = -0.92+-nan
# Jonathan Johnson, sentimiento = 1.00+-nan
# Jonathan Keane, sentimiento = 0.07+-0.29
# Jonathan Levin, sentimiento = -0.00+-0.08
# Joon Ian Wong, sentimiento = 0.16+-0.43
# Jose Pagliery, sentimiento = 1.00+-nan
# Joseph Bonneau, sentimiento = -0.65+-nan
# Josh Fineman, sentimiento = 0.13+-0.33
# Josh Metnick, sentimiento = 1.00+-nan
# Joshua Oliver, sentimiento = 1.00+-nan
# José Rafael Peña Gholam, sentimiento = 0.02+-0.16
# Justin O'Connell, sentimiento = 1.00+-nan
# Kadhim Shubber, sentimiento = 0.17+-0.43
# Kathryn &amp; Nick, sentimiento = -0.99+-nan
# Keith Horwood, sentimiento = 0.01+-0.08
# Ken Abe, sentimiento = 0.99+-nan
# Kevin Reynolds, sentimiento = 0.04+-0.29
# Kim Byung Chul, sentimiento = 1.00+-nan
# Konstantinos Stylianou, sentimiento = 1.00+-nan
# Kosala Hemachandra, sentimiento = 1.00+-nan
# Krisztian  Sandor, sentimiento = 0.30+-0.69
# Lanre Sarumi, sentimiento = 1.00+-nan
# Lavender Au, sentimiento = 0.05+-0.23
# Lawrence Lewitinn, sentimiento = 0.02+-0.14
# Leah Callon-Butler, sentimiento = 0.01+-0.09
# Leigh Cuen, sentimiento = 0.32+-0.63
# Leslie Starr O'Hara, sentimiento = 1.00+-nan
# Lingling Xiang, sentimiento = 0.97+-nan
# Louise Goss, sentimiento = 0.05+-0.21
# Lucas Marins, sentimiento = 0.62+-nan
# Luis Buenaventura, sentimiento = 0.02+-0.15
# Lyllah Ledesma, sentimiento = 0.26+-0.63
# Madeline Meng Shi, sentimiento = 0.45+-0.79
# Maja Vujinovic, sentimiento = 1.00+-nan
# Marc Hochstein, sentimiento = 0.03+-0.19
# Marc Hochstein &amp; Bailey Reutzel, sentimiento = 0.30+-nan
# Marc van der Chijs, sentimiento = 0.02+-0.12
# Marco Santori, sentimiento = 0.00+-0.06
# Margaux Nijkerk, sentimiento = 0.20+-0.50
# Marie Le Conte, sentimiento = 0.43+-0.51
# Marina Lammertyn, sentimiento = 0.00+-0.18
# Martin Harrigan, sentimiento = -0.38+-nan
# Martin Pasquier, sentimiento = 1.00+-nan
# Martine Paris, sentimiento = 1.00+-nan
# Mary Ernst, sentimiento = 1.00+-nan
# Matt Mihaly, sentimiento = 1.00+-nan
# Matt Yamamoto, sentimiento = 0.02+-0.14
# Matthew Burgoyne, sentimiento = 0.05+-0.21
# Matthew Leising, sentimiento = 1.00+-nan
# Matthew Trudeau, sentimiento = 1.00+-nan
# Max Boonen, sentimiento = 0.10+-nan
# Maziar Motamedi, sentimiento = 0.01+-0.12
# Meena Thiruvengadam, sentimiento = 0.99+-nan
# Mic Bowman, sentimiento = 1.00+-nan
# Michael Bellusci, sentimiento = 0.36+-0.65
# Michael J. Casey, sentimiento = 0.00+-0.06
# Michael Jackson, sentimiento = 0.03+-0.16
# Michael Kapilkov, sentimiento = 1.00+-nan
# Michael del Castillo, sentimiento = 0.63+-0.78
# Michael del Castillo &amp; Alyssa Hertig, sentimiento = -0.82+-nan
# Michael del Castillo &amp; Bailey Reutzel, sentimiento = 1.00+-nan
# Michelle Bloom, sentimiento = 0.12+-0.33
# Michelle Urban, sentimiento = 0.99+-nan
# Mike Hearn, sentimiento = 0.01+-0.07
# Milena Ciric, sentimiento = 0.65+-0.56
# Morgen Peck, sentimiento = 0.01+-0.16
# Muyao Shen, sentimiento = 0.18+-0.54
# Myles Sherman, sentimiento = 0.16+-0.45
# Naomi Brockwell, sentimiento = 1.00+-nan
# Nate DiCamillo, sentimiento = 0.38+-0.67
# Nathaniel Popper, sentimiento = -0.97+-nan
# Nathaniel Whittemore, sentimiento = 0.10+-0.38
# Neil Murray, sentimiento = 0.97+-nan
# Nelson Wang, sentimiento = 0.08+-0.35
# Nermin Hajdarbegovic, sentimiento = 0.52+-0.92
# Nic Carter, sentimiento = 1.00+-nan
# Nicholas Tomaino, sentimiento = 0.03+-0.16
# Nick Baker, sentimiento = 0.03+-0.23
# Nick Chowdrey, sentimiento = 0.04+-0.19
# Nik Custodio, sentimiento = 1.00+-nan
# Nik De &amp; Michael del Castillo, sentimiento = 0.93+-nan
# Nikhilesh De, sentimiento = 0.47+-0.95
# Nikhilesh De &amp; Stan Higgins, sentimiento = -0.43+-nan
# Nina Xiang, sentimiento = 0.03+-0.17
# Noelle Acheson, sentimiento = 0.02+-0.14
# Nolan Bauerle, sentimiento = 0.00+-0.07
# Nozomi Hayase, sentimiento = 0.05+-0.22
# Oleg Andreev, sentimiento = 1.00+-nan
# Oliver Knight, sentimiento = 0.19+-0.57
# Olivia Rudgard, sentimiento = 0.99+-nan
# Ollie Leech, sentimiento = 0.02+-0.18
# Omkar Godbole, sentimiento = 0.36+-0.83
# Paddy Baker, sentimiento = 0.35+-0.88
# Parikshit Mishra, sentimiento = 0.03+-0.27
# Patrick Foot, sentimiento = 0.97+-nan
# Paul Brody, sentimiento = 1.00+-nan
# Paul Elliot-Ennis &amp; Rachel-Rose O'Leary, sentimiento = 0.95+-nan
# Paulo Alves, sentimiento = 0.03+-0.21
# Pavel Matveev, sentimiento = 1.00+-nan
# Pete Pachal, sentimiento = 0.00+-0.06
# Pete Rizzo, sentimiento = 0.54+-0.90
# Pete Rizzo &amp; Alyssa Hertig, sentimiento = 0.01+-0.11
# Pete Rizzo &amp; Stan Higgins, sentimiento = 1.21+-nan
# Pete Rizzo and Rachel Rose O'Leary, sentimiento = 0.99+-0.01
# Peter Nicholls, sentimiento = -0.99+-nan
# Peter Oakes, sentimiento = 0.98+-nan
# Peter Ryan, sentimiento = 0.01+-0.07
# Pindar Wong, sentimiento = 0.99+-nan
# Preston J. Byrne, sentimiento = -0.96+-nan
# Rachel-Rose O'Leary, sentimiento = 0.14+-0.51
# Radoslav Albrecht, sentimiento = 1.00+-nan
# Randy Wilson, sentimiento = 1.00+-nan
# Reuben Youngblom, sentimiento = 1.00+-nan
# Richard Boase, sentimiento = 0.06+-0.28
# Richard Brown, sentimiento = 0.00+-0.03
# Richard Meyer, sentimiento = 0.38+-0.53
# Rob Wile, sentimiento = 0.06+-0.20
# Robert Paul Davis, sentimiento = 0.07+-0.27
# Robert Roessler, sentimiento = 1.00+-nan
# Robert Stevens, sentimiento = -0.91+-nan
# Robert Viglione, sentimiento = 0.97+-nan
# Robin Dhara, sentimiento = 0.99+-nan
# Rodrigo   Tolotti, sentimiento = 0.03+-0.16
# Roop Gill, sentimiento = 0.21+-0.51
# Rosie Perper, sentimiento = 0.02+-0.16
# Rui Ma, sentimiento = 1.00+-nan
# Ryan Selkis, sentimiento = 0.17+-0.48
# Ryan Walker, sentimiento = 1.00+-nan
# Sage D. Young, sentimiento = 0.12+-0.42
# Sam Kessler, sentimiento = 0.07+-0.44
# Sam Ouimet, sentimiento = 0.06+-0.30
# Sam Reynolds, sentimiento = 0.19+-0.56
# Sandali Handagama, sentimiento = 0.15+-0.51
# Sandrine Ayral, sentimiento = 0.02+-0.14
# Sanne Wass, sentimiento = 0.16+-0.35
# Sarah Boone Martin, sentimiento = 1.00+-nan
# Scott Rose, sentimiento = 0.99+-nan
# Sebastian Sinclair, sentimiento = 0.30+-0.73
# Shaurya Malwa, sentimiento = 0.52+-1.04
# Sheldon Reback, sentimiento = 0.01+-0.14
# Shenna Peter, sentimiento = 0.99+-nan
# Shinjae Yoo &amp; Hyeong-joong Yoon, sentimiento = 1.00+-nan
# Shirley Siluk, sentimiento = 0.41+-0.84
# Sid Kalla, sentimiento = 0.02+-0.14
# Simon Johnson, sentimiento = 0.00+-0.05
# Siobhan Fenton, sentimiento = 0.97+-nan
# Sophia Zaller, sentimiento = 1.00+-nan
# Stan Higgins, sentimiento = 0.47+-1.00
# Stan Higgins, Alex Sunnarborg &amp; Pete Rizzo, sentimiento = 0.98+-nan
# Stephanie Izquieta, sentimiento = 0.01+-0.10
# Stephen  Alpher, sentimiento = 0.08+-0.35
# Sujha Sundararajan, sentimiento = 0.44+-0.91
# Tanaya Macheel, sentimiento = 0.17+-0.44
# Tanzeel Akhtar, sentimiento = 0.39+-0.71
# Thomas Kerin, sentimiento = 1.00+-nan
# Tian Chuan &amp; Rachel-Rose O'Leary, sentimiento = -0.12+-0.27
# Tim Draper, sentimiento = 1.00+-nan
# Tim Swanson, sentimiento = 0.01+-0.11
# Timothy C. May, sentimiento = 1.00+-nan
# Todd Bryant, sentimiento = 1.00+-nan
# Todd Groth, CFA, sentimiento = 1.00+-nan
# Tom Higginson, sentimiento = 1.00+-nan
# Tom Sharkey, sentimiento = 0.07+-0.28
# Tracy Wang, sentimiento = 0.12+-0.37
# Travis Patron, sentimiento = 0.99+-nan
# Tuur Demeester, sentimiento = 0.98+-nan
# Vasilije Markovic, sentimiento = -0.95+-nan
# Victoria van Eyk, sentimiento = 0.01+-0.17
# Vinamrata Chaturvedi, sentimiento = 0.11+-0.30
# Vitalik Buterin, sentimiento = 1.00+-nan
# Will Canny, sentimiento = 0.22+-0.49
# Will Gottsegen, sentimiento = 0.13+-0.36
# Will O’Brien, sentimiento = 1.00+-nan
# William Coates, sentimiento = 1.00+-nan
# William Foxley, sentimiento = 0.39+-0.78
# William McCanless, sentimiento = 0.73+-0.88
# William Mougayar, sentimiento = 0.00+-0.04
# Willy Woo, sentimiento = 0.94+-nan
# Wolfie Zhao, sentimiento = 0.33+-0.83
# Xiang Wang, sentimiento = 0.74+-nan
# Xinyi Luo, sentimiento = 0.06+-0.39
# Yael Grauer, sentimiento = 0.51+-nan
# Yao Qian, sentimiento = 1.00+-nan
# Yessi Bello Perez, sentimiento = 0.45+-0.74
# Yogita Khatri, sentimiento = 1.29+-1.40
# Zack Seward, sentimiento = 0.09+-0.30
# Zack Voell, sentimiento = 0.27+-0.54

# %% [markdown]
# Los autores con una std nan es porque solo publicaron una noticia:

# %%
# Agrupamos el df por la columna autor y calculamos el recuento de valores NO Cero
df_clean.groupby('author').agg(np.count_nonzero)
# Out:
#                      id  url  title  content  sentiment
# author
#  Deirdra  Funcheon    7    7      7        7          7
# Aaron Stanley        58   58     58       58         57
# Aaron van Wirdum      7    7      7        6          6
# Ada Hui              30   30     30       30         29
# Adam B. Levine      180  180    180      177        161
# ...                 ...  ...    ...      ...        ...
# Yao Qian              1    1      1        1          1
# Yessi Bello Perez   318  318    318      317        315
# Yogita Khatri       542  542    542      541        538
# Zack Seward         147  147    147      147        143
# Zack Voell          263  263    263      243        197
#
# [423 rows x 5 columns]

# %% [markdown]
# Ahora vamos a realizar una agrupación para conocer la cantidad de autores sesgados a un sentimiento positivo, negativo y a uno neutro

# %%
# Convertir a df
dict_author = {'author': autores, 'mean_sentiment': means, 'std_sentiment': stds}
df_authors = pd.DataFrame(dict_author)

# Ver el sesgo de cada autor,
# Neutral: [-0.5, 0.5]
# Positivo: > 0.5
# Negativo: < -0.5
def sesgo(x):
    if x > 0.5:
        return 'Positivo' 
    elif x < -0.5:
        return 'Negativo'
    else:
        return 'Neutral'
    
df_authors['sesgo'] = df_authors['mean_sentiment'].apply(lambda x: sesgo(x))
df_authors.groupby('sesgo').agg(np.count_nonzero)
# Out:
#           author  mean_sentiment  std_sentiment
# sesgo
# Negativo      14              14             14
# Neutral      233             232            232
# Positivo     176             176            176

# %% [markdown]
# Vemos como la mayoria de los autores tienen un sesgo que podemos considerar neutral (233/423), seguido con sesgo positivo (176/423) y solo 14 (que es muy poco) con sesgo negativo.

# %% [markdown]
# # Interfaz Gradio para ver la evolución de las anomalias y el Resultado Global de la estrategia

# %%
# Calculo del df de anomalias
anomalias = df_sum[(df_sum['positive_anomalie_index']==1)|(df_sum['negative_anomalie_index']==1)]
#anomalias[['positive_anomalie_index', 'negative_anomalie_index', 'rolling_zscore_sentiment']]

# %%
# Calculo de la Estrategia
# Creamos un df copia del subconjunto del df_ohlcv desde ini_fecha hasta fin_fecha
ini_fecha = anomalias.index[0] - pd.Timedelta(days=14)
fin_fecha = anomalias.index[anomalias.shape[0] - 1] + pd.Timedelta(days=14)
df_returns_strategy = df_ohlcv.loc[ini_fecha:fin_fecha].copy()

# Creamos una nueva columna de log_returns_strategy
df_returns_strategy.loc[:, 'log_returns_strategy'] = 0.0

# Recorremos las anomalias enumerandolas para extraer el indice y el valor de la anomalia
for i, date in enumerate(anomalias.index):
    # Calculo el inicio de la operacion y el signo segun la anomalia
    inicio_operacion = date + pd.Timedelta(days=1)
    signo_anomalia = np.sign(anomalias.iloc[i]['rolling_zscore_sentiment'])
    
    # Determino el final_operacion a la fecha mas proxima entre 7 dias después de la anomalia y la 
    # anomalia siguiente, siempre que la anomalia no sea la ultima en cuyo caso no habrá proxima anomalia
    final_operacion = min(date + pd.Timedelta(days=7), 
                          anomalias.index[i+1] if date < anomalias.index[anomalias.shape[0] - 1] 
                          else date + pd.Timedelta(days=7))
    
    # Calculamos los retornos de la operacion y sumamos los retornos que hay 
    retornos_sum = df_returns_strategy.loc[inicio_operacion:final_operacion, 'log_returns']
    
    # Añado los retornos*signo (ya que compra suman y en venta restan) al df_returns_strategy 
    df_returns_strategy.loc[inicio_operacion:final_operacion,'log_returns_strategy'] = retornos_sum * signo_anomalia
                          
# Añadimos una columna de los retornos acumulados, los retornos lineales y los porcentuales
df_returns_strategy['cum_log_returns_strategy']= df_returns_strategy['log_returns_strategy'].cumsum()
df_returns_strategy['returns_strategy_lineales']= (np.exp(df_returns_strategy['cum_log_returns_strategy']) - 1.0)
df_returns_strategy['returns_strategy_porcentuales']= (np.exp(df_returns_strategy['cum_log_returns_strategy']) - 1.0)*100

# Vemos el final del df
# df_returns_strategy.head(33)

# %%
# Calculo de los Retornos hold en ese periodo
horizon = 14
fecha = anomalias.index[0]
index_ini = fecha - pd.Timedelta(days=horizon)
index_fin = fecha + pd.Timedelta(days=horizon)

# Creamos un df retornos_hold como copia de un subconjunto de df_ohlcv
retornos_hold = df_ohlcv.loc[index_ini:,['close', 'open']].copy()

# Se crean la columna log_returns y se rellena en el df (inplace=True) el elemento Na por 0
retornos_hold['log_returns'] = np.log(retornos_hold['close']/retornos_hold['close'].shift(1))
retornos_hold.fillna(0, inplace=True)

# Se crean las columnas retornos_hold, retornos_hold_lineales y retornos_hold_porcentuales
retornos_hold['retornos_hold'] = retornos_hold['log_returns'].cumsum()
retornos_hold['retornos_hold_lineales'] = (np.exp(retornos_hold['retornos_hold']) - 1.0)
retornos_hold['retornos_hold_porcentuales'] = (np.exp(retornos_hold['retornos_hold']) - 1.0)*100
#retornos_hold

# %%
# Grafico para ver la diferencia entre los retornos de la estrategia y los retornos hold
plt.figure(figsize=(20, 10))
plt.plot(retornos_hold['retornos_hold'], label='Estrategia hold')
plt.plot(df_returns_strategy['cum_log_returns_strategy'], label='Estrategia en base anomalias')
plt.legend()
plt.ylabel('Retorno logaritmico acumulado (%)')
plt.show()

# %%
# -------------------------------------------- GRADIO -----------------------------------------
# Defino el indice global para iterar las anomalias
global index
index = -1

def convert_nummonth_to_text(nmonth):
    # Convertir el nmonth a entero para usarlo en los if
    month_number = int(nmonth)
    
    # Checkear en que caso estamos
    if month_number == 1:
        return 'Enero'
    elif month_number == 2:
        return 'Febrero'
    elif month_number == 3:
        return 'Marzo'
    elif month_number == 4:
        return 'Abril'
    elif month_number == 5:
        return 'Mayo'
    elif month_number == 6:
        return 'Junio'
    elif month_number == 7:
        return 'Julio'
    elif month_number == 8:
        return 'Agosto'
    elif month_number == 9:
        return 'Septiembre'
    elif month_number == 10:
        return 'Octubre'
    elif month_number == 11:
        return 'Noviembre'
    elif month_number == 12:
        return 'Diciembre'

def convert_fecha_to_text(fecha):
    # Pasar fecha a string
    fecha_string = str(fecha)
    
    # Dividir la fecha al espacio en blanco
    fecha_string = fecha_string.split(' ')
    
    # Split de la fecha a partir del primer elemento de fecha_string
    fecha_split = fecha_string[0].split('-')
    
    # Obtener el nombre del mes 
    month_text = convert_nummonth_to_text(fecha_split[1])
    
    # Crear el Mensaje y return del mismo
    message = str(fecha_split[2]) + ' de ' + month_text + ' del ' + str(fecha_split[0])
    return message

def convert_sign_to_text(sentimiento):
    # Calculamos el signo
    signo = np.sign(sentimiento)
    
    # Checkeamos el signo
    if signo == -1:
        # El signo es negativo
        return 'Negativa'   
    else:
        # El signo es positivo
        return 'Positiva' 
    
def get_next_anomaly_index(plot_type):
    # Cambiar el indice global index
    global index
    index = index + 1
       
    # Generamos el dataset de las anomalias, juntamos los casos de anomalia positiva y negativa
    anomalias = df_sum[(df_sum['positive_anomalie_index']==1)|(df_sum['negative_anomalie_index']==1)]
    
    # Obtenemos la fecha de la anomalia y el signo del sentimiento para decir si la anomalia 
    # es positiva o negativa
    anomaly_date = anomalias.iloc[index].name
   
    # sentiment_anomaly = np.sign(anomalias.iloc[index].rolling_zscore_sentiment)
    sentiment_anomaly = anomalias.iloc[index].rolling_zscore_sentiment
    
    # Pasamos la informacion como input a una función que plotea las cotizaciones en estas fechas
    return plot_anomaly_subplots(anomaly_date, sentiment_anomaly, plot_type)

def get_prev_anomaly_index(plot_type):
    # Cambiar el indice global index
    global index
    index = index - 1
       
    # Generamos el dataset de las anomalias, juntamos los casos de anomalia positiva y negativa
    anomalias = df_sum[(df_sum['positive_anomalie_index']==1)|(df_sum['negative_anomalie_index']==1)]
    
    # Obtenemos la fecha de la anomalia y el signo del sentimiento para decir si la anomalia 
    # es positiva o negativa
    anomaly_date = anomalias.iloc[index].name
   
    # sentiment_anomaly = np.sign(anomalias.iloc[index].rolling_zscore_sentiment)
    sentiment_anomaly = anomalias.iloc[index].rolling_zscore_sentiment
    
    # Pasamos la informacion como input a una función que plotea las cotizaciones en estas fechas
    return plot_anomaly_subplots(anomaly_date, sentiment_anomaly, plot_type)

def plot_anomaly_subplots(fecha, sentimiento_anomalia, plot_type):
    # Generamos la grafica de velas + la localizacion de la anomalia
    fig = make_subplots(rows=2, cols=1, shared_xaxes=True, vertical_spacing=0.1)
    
    # Grafico de velas 
    horizon = 14
    index_ini = fecha - pd.Timedelta(days=horizon)
    index_fin = fecha + pd.Timedelta(days=horizon)
    local_ohlcv = df_ohlcv.loc[index_ini:index_fin]
    fig.add_trace(go.Candlestick(
        x=local_ohlcv.index,
        open=local_ohlcv['open'],
        high=local_ohlcv['high'],
        low=local_ohlcv['low'],
        close=local_ohlcv['close'],
        name='OHLCV'), row=1, col=1)
    
    # Añadir la localización de la anomalia con un color según su sentimiento
    fig.add_trace(go.Scatter(
        x=[fecha],
        y=[local_ohlcv.loc[fecha, 'close']],
        text=[sentimiento_anomalia],
        mode='markers',
        marker=dict(
            color= 'green' if sentimiento_anomalia > 0 else 'red',
            size=10,
            symbol='circle',
            line=dict(
                width=2,
                color='#00FFFF'
            )
        ),
        name='Anomalia'), row=1, col=1)
    # Añadir la evolución de los retornos logaritmicos de la estrategia
    fechas = pd.date_range(start=index_ini, end=index_fin, freq='D')
    
    # Cambiar los ejes segun el plot_type
    if plot_type == 'Logaritmico':
        fig.add_trace(go.Line(
            x=fechas,
            y=df_returns_strategy.loc[index_ini:index_fin, 'cum_log_returns_strategy'],
            name='Strategy'), row=2, col=1)
        
        fig.add_trace(go.Line(
            x=fechas,
            y=retornos_hold.loc[index_ini:index_fin, 'retornos_hold'],
            name='Hold'), row=2, col=1)
        
        # Cambiamos el texto de los ejes 
        fig.update_yaxes(title_text='Precio ($)', row=1, col=1)
        fig.update_yaxes(title_text='Retornos (log)', row=2, col=1)
        fig.update_xaxes(title_text='Fecha', row=2, col=1)
        fig.update_layout(title_text='Sentiment buys', title_font_size=20, xaxis_rangeslider_visible=False,
                          legend=dict(
                              orientation="h",
                              yanchor="bottom",
                              y=1.02,
                              xanchor="right",
                              x=1)
                          )
        
    elif plot_type == 'Lineal':
        fig.add_trace(go.Line(
            x=fechas,
            y=df_returns_strategy.loc[index_ini:index_fin, 'returns_strategy_lineales'],
            name='Strategy'), row=2, col=1)
        
        fig.add_trace(go.Line(
            x=fechas,
            y=retornos_hold.loc[index_ini:index_fin, 'retornos_hold_lineales'],
            name='Hold'), row=2, col=1)
        
        # Cambiamos el texto de los ejes 
        fig.update_yaxes(title_text='Precio ($)', row=1, col=1)
        fig.update_yaxes(title_text='Retornos (lin)', row=2, col=1)
        fig.update_xaxes(title_text='Fecha', row=2, col=1)
        fig.update_layout(title_text='Sentiment buys', title_font_size=20, xaxis_rangeslider_visible=False,
                          legend=dict(
                              orientation="h",
                              yanchor="bottom",
                              y=1.02,
                              xanchor="right",
                              x=1)
                          )
        
    elif plot_type == 'Porcentual':
        fig.add_trace(go.Line(
            x=fechas,
            y=df_returns_strategy.loc[index_ini:index_fin, 'returns_strategy_porcentuales'],
            name='Strategy'), row=2, col=1)
        
        fig.add_trace(go.Line(
            x=fechas,
            y=retornos_hold.loc[index_ini:index_fin, 'retornos_hold_porcentuales'],
            name='Hold'), row=2, col=1)
        
        # Cambiamos el texto de los ejes 
        fig.update_yaxes(title_text='Precio ($)', row=1, col=1)
        fig.update_yaxes(title_text='Retornos (%)', row=2, col=1)
        fig.update_xaxes(title_text='Fecha', row=2, col=1)
        fig.update_layout(title_text='Sentiment Buys', title_font_size=20, xaxis_rangeslider_visible=False,
                          legend=dict(
                              orientation="h",
                              yanchor="bottom",
                              y=1.02,
                              xanchor="right",
                              x=1)
                          )
     
    # Retornamos la figura
    return fig, convert_fecha_to_text(fecha), convert_sign_to_text(sentimiento_anomalia)

def plot_fullstrategy_and_hold(plot_type):
    # Defino el grafico
    fig = go.Figure()
    
    # Defino Fechas
    fechas = df_returns_strategy.index
    
    # Checkear el tipo de plot_type
    if plot_type == 'Logaritmico':
        fig.add_trace(go.Scatter(
            x=fechas,
            y=df_returns_strategy['cum_log_returns_strategy'],
            mode='lines',
            line=dict(color='seagreen'),
            name='Strategy'))
        
        fig.add_trace(go.Scatter(
            x=fechas,
            y=retornos_hold['retornos_hold'],
            mode='lines',
            line=dict(color='blueviolet'),
            name='Hold'))
        
        # Cambiamos el texto de los ejes 
        fig.update_yaxes(title_text='Retornos (log)')
        fig.update_xaxes(title_text='Fecha')
        fig.update_layout(title_text='Strategy vs Hold', title_font_size=20, xaxis_rangeslider_visible=False,
                          legend=dict(
                              orientation="h",
                              yanchor="bottom",
                              y=1.02,
                              xanchor="right",
                              x=1)
                          )
        
    elif plot_type == 'Lineal':
        fig.add_trace(go.Scatter(
            x=fechas,
            y=df_returns_strategy['returns_strategy_lineales'],
            mode='lines',
            line=dict(color='seagreen'),
            name='Strategy'))
        
        fig.add_trace(go.Scatter(
            x=fechas,
            y=retornos_hold['retornos_hold_lineales'],
            mode='lines',
            line=dict(color='blueviolet'),
            name='Hold'))
        
        # Cambiamos el texto de los ejes 
        fig.update_yaxes(title_text='Retornos (lin)')
        fig.update_xaxes(title_text='Fecha')
        fig.update_layout(title_text='Strategy vs Hold', title_font_size=20, xaxis_rangeslider_visible=False, 
                          legend=dict(
                              orientation="h",
                              yanchor="bottom",
                              y=1.02,
                              xanchor="right",
                              x=1)
                          )
        
    elif plot_type == 'Porcentual':
        fig.add_trace(go.Scatter(
            x=fechas,
            y=df_returns_strategy['returns_strategy_porcentuales'],
            mode='lines',
            line=dict(color='seagreen'),
            name='Strategy'))
        
        fig.add_trace(go.Scatter(
            x=fechas,
            y=retornos_hold['retornos_hold_porcentuales'],
            mode='lines',
            line=dict(color='blueviolet'),
            name='Hold'))
        
        # Cambiamos el texto de los ejes 
        fig.update_yaxes(title_text='Retornos (%)')
        fig.update_xaxes(title_text='Fecha')
        fig.update_layout(title_text='Strategy vs Hold', title_font_size=20, xaxis_rangeslider_visible=False,
                          legend=dict(
                              orientation="h",
                              yanchor="bottom",
                              y=1.02,
                              xanchor="right",
                              x=1)
                          )
     
    # Retornamos la figura
    return fig
    
# APP
with gr.Blocks() as demo:
    with gr.Tab("Anomalias Individuales"):
        # 1) Objeto Output de Radio
        radio = gr.Radio(['Logaritmico', 'Lineal', 'Porcentual'], value='Logaritmico',label='¿Que tipo de retornos mostrar?')
        
        # 2) Objetos Output de texto
        with gr.Row():
            output_text1 = gr.Text(label="Fecha de la Anomalia")
            output_text2 = gr.Text(label="Tipo de la Anomalia")
            
        # 3) Objeto Output de Plot
        output_plot = gr.Plot()
        
        # 4) Botones de siguiente y previo en una misma linea
        with gr.Row():
            if index >= 0:
                button_prev = gr.Button(value="Previous")
                button_next = gr.Button(value="Next")
            else: 
                button_prev = gr.Button(value="Last")
                button_next = gr.Button(value="First")
            
        # Acciones de los botones
        button_next.click(fn=get_next_anomaly_index, inputs=radio, outputs=[output_plot, output_text1, output_text2])
        button_prev.click(fn=get_prev_anomaly_index, inputs=radio, outputs=[output_plot, output_text1, output_text2])
        
    with gr.Tab("Resultado Global"):
        # 1) Fila con objeto radio y objeto columna con un texto y un boton 
        with gr.Row():
            radio = gr.Radio(['Logaritmico', 'Lineal', 'Porcentual'], 
                             value='Logaritmico',label='¿Que tipo de retornos mostrar?')
            
            with gr.Column():
                gr.Markdown("Realizar Gráfico:")
                button_launch = gr.Button(value="Plot")
            
        # 2) Objecto Plot
        output_plot2 = gr.Plot()
        
        # 3) Representar graficos dependiendo de radio
        button_launch.click(fn=plot_fullstrategy_and_hold, inputs=radio, outputs=[output_plot2])
        
demo.launch()
# Out:
# Running on local URL:  http://127.0.0.1:7860
#
# To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7860/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
# Detener la aplicación Gradio
demo.close()
# Out:
# Closing server running on port: 7860
